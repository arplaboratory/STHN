# %%
import numpy as np 

import matplotlib.pyplot as plt
import os, sys
import random
import h5py

# %%
def plotimg(root):
    file_dir = root
    if file_dir.split('.')[-1] == 'h5':
        h = h5py.File(file_dir, 'r')
        size = h['image_size'].shape[0]
        dim = h['image_data'][0].shape
        print("name: {}, dataset_size: {}, image_dim: {}" .format(file_dir, size, dim))
        dict = {}
        for i in range(len(h['image_name'])):
            dict[h['image_name'][i]] = i
        # i = dict[b'@1471@1936']
        i = 0
        print(i)
        # i = 0
        img = h['image_data'][i]
        print(img.min())
        print(h['image_name'][i])
        plt.imshow(img)
        plt.show()
        # for i in range(20):
        #     img = h['image_data'][i]
        #     print(h['image_name'][i])
        #     plt.imshow(img)
        #     plt.show()

# %%
plotimg('datasets/satellite_0_thermalmapping_135/val_queries.h5')
# Out:
# name: datasets/satellite_0_thermalmapping_135/val_queries.h5, dataset_size: 13011, image_dim: (512, 512, 3)
# 0
# 88
# @2956@5906

# %%
plotimg('./datasets/satellite_0_thermalmapping_135_nocontrast_dense_exclusion_large_train/val_database.h5')
# Out:
# name: ./datasets/satellite_0_thermalmapping_135/val_database.h5, dataset_size: 13011, image_dim: (512, 512, 3)
# 0
# @2956@5906

# %%
plotimg('./datasets/satellite_0_thermalmapping_135_nocontrast_dense_exclusion_larger_ori_train/val_database.h5')
# Out:
# name: ./datasets/satellite_0_thermalmapping_135/val_database.h5, dataset_size: 13011, image_dim: (512, 512, 3)
# 0
# @2956@5906

# %%
plotimg('./datasets/satellite_0_thermalmapping_135_nocontrast_dense_exclusion/val_database.h5')
# Out:
# name: ./datasets/satellite_0_thermalmapping_135/val_database.h5, dataset_size: 13011, image_dim: (512, 512, 3)
# 0
# @2956@5906
